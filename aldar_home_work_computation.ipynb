# %% [markdown]
# This notebook calculates work and home locations on where the users opened the app

# %%
# %sql
use aldar
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# %sql
Show Tables;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>aldar</td><td>event_info</td><td>false</td></tr><tr><td>aldar</td><td>filter_info</td><td>false</td></tr><tr><td>aldar</td><td>geolocation_info</td><td>false</td></tr><tr><td>aldar</td><td>search_info</td><td>false</td></tr><tr><td>aldar</td><td>session_info</td><td>false</td></tr><tr><td>aldar</td><td>tmp</td><td>false</td></tr></tbody></table></div>

# %%
# %python
df = spark.table("geolocation_info")
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+------------+-------------------+-------------------+-----------+---------+-----------+---------+--------------------+
#                   id|company_code|       created_date|         created_on|customer_id|      lat|location_id|      lon|          session_id|
# +--------------------+------------+-------------------+-------------------+-----------+---------+-----------+---------+--------------------+
# 5fe5fe9ee3a7b8fb5...|         adr|2020-12-25 18:43:17|2020-12-25 15:00:46|    5586627|24.489145|          2|54.611362|          1608907398|
# ...

# %%
# Checking if all the users are aldar users
df.select('company_code').distinct().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------+
# company_code|
# +------------+
#          adr|
# +------------+
#
# </div>

# %%
##Filter Aldar customers
df=df[df.company_code=='adr']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#df=df[df.location_id.isin([1,2,10,18,49,3,8,9,7])] #4,11,14,20
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.select('location_id').distinct().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+
# location_id|
# +-----------+
#           0|
#           2|
# +-----------+
#
# </div>

# %%
df.select('customer_id').distinct().count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[223]: 17739</div>

# %%
df=df[df.customer_id!='0']
df=df[df.location_id!='0']
df=df[df.lat!='0']
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+------------+-------------------+-------------------+-----------+---------+-----------+---------+--------------------+
#                   id|company_code|       created_date|         created_on|customer_id|      lat|location_id|      lon|          session_id|
# +--------------------+------------+-------------------+-------------------+-----------+---------+-----------+---------+--------------------+
# 5f92e74de3a7b85e5...|         adr|2020-10-23 17:46:57|2020-10-23 14:23:09|   10092921|24.432276|          2| 54.57541|          1603460818|
# ...

# %%
df.select('location_id').distinct().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+
# location_id|
# +-----------+
#           2|
# +-----------+
#
# </div>

# %%
# Total Unique Record
df.distinct().count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[226]: 347030</div>

# %%
# Total Unique Customers
df.select('customer_id').distinct().count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[227]: 16118</div>

# %%
# %python
df=df.drop('id','session_id','company_code','location_id')
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+-------------------+-----------+---------+---------+
#        created_date|         created_on|customer_id|      lat|      lon|
# +-------------------+-------------------+-----------+---------+---------+
# 2020-10-23 17:46:57|2020-10-23 14:23:09|   10092921|24.432276| 54.57541|
# 2020-10-23 17:48:13|2020-10-23 14:23:11|   10092921| 24.43226|54.575462|
# 2020-10-17 13:02:15|2020-10-23 14:23:13|   11186054|24.346224| 54.61789|
# 2020-10-17 13:06:21|2020-10-23 14:23:21|   11186054|24.345835|54.617813|
# 2020-10-17 13:06:57|2020-10-23 14:23:23|   11186054|24.346115|54.617805|
# ...

# %%
df.agg({'created_date': 'min'}).show()
df.agg({'created_date': 'max'}).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+
#   min(created_date)|
# +-------------------+
# 0002-11-01 20:27:21|
# +-------------------+
#
# +-------------------+
#   max(created_date)|
# +-------------------+
# 2021-02-21 00:47:25|
# +-------------------+
#
# </div>

# %%
df.agg({'created_on': 'min'}).show()
df.agg({'created_on': 'max'}).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+
#     min(created_on)|
# +-------------------+
# 2020-10-16 11:10:35|
# +-------------------+
#
# +-------------------+
#     max(created_on)|
# +-------------------+
# 2021-02-21 03:00:02|
# +-------------------+
#
# </div>

# %%
from pyspark.sql.functions import *
df = df.withColumn('year',year(df.created_date))
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+-------------------+-----------+---------+---------+----+
#        created_date|         created_on|customer_id|      lat|      lon|year|
# +-------------------+-------------------+-----------+---------+---------+----+
# 2020-10-23 17:46:57|2020-10-23 14:23:09|   10092921|24.432276| 54.57541|2020|
# 2020-10-23 17:48:13|2020-10-23 14:23:11|   10092921| 24.43226|54.575462|2020|
# 2020-10-17 13:02:15|2020-10-23 14:23:13|   11186054|24.346224| 54.61789|2020|
# 2020-10-17 13:06:21|2020-10-23 14:23:21|   11186054|24.345835|54.617813|2020|
# 2020-10-17 13:06:57|2020-10-23 14:23:23|   11186054|24.346115|54.617805|2020|
# ...

# %%
df.select('year').distinct().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+
# year|
# +----+
# null|
# 2020|
# 2021|
#    2|
# +----+
#
# </div>

# %%
df[(df.year=='2')].count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[233]: 8</div>

# %%
df[(df.year=='2')].select('customer_id').distinct().count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[235]: 1</div>

# %%
df[(isnull(df.year))].count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[234]: 14</div>

# %%
df[(isnull(df.year))].select('customer_id').distinct().count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[236]: 4</div>

# %%
df=df[(df.year=='2020') | (df.year=='2021')]
df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+-------------------+-----------+---------+---------+----+
#        created_date|         created_on|customer_id|      lat|      lon|year|
# +-------------------+-------------------+-----------+---------+---------+----+
# 2020-10-23 17:46:57|2020-10-23 14:23:09|   10092921|24.432276| 54.57541|2020|
# 2020-10-23 17:48:13|2020-10-23 14:23:11|   10092921| 24.43226|54.575462|2020|
# 2020-10-17 13:02:15|2020-10-23 14:23:13|   11186054|24.346224| 54.61789|2020|
# 2020-10-17 13:06:21|2020-10-23 14:23:21|   11186054|24.345835|54.617813|2020|
# 2020-10-17 13:06:57|2020-10-23 14:23:23|   11186054|24.346115|54.617805|2020|
# ...

# %%
df.agg({'created_date': 'max'}).show()
df.agg({'created_date': 'min'}).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+
#   max(created_date)|
# +-------------------+
# 2021-02-21 00:47:25|
# +-------------------+
#
# +-------------------+
#   min(created_date)|
# +-------------------+
# 2020-08-07 18:04:27|
# +-------------------+
#
# </div>

# %%
print(df.select('customer_id').distinct().count())
print(df.distinct().count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">16117
# 337826
# </div>

# %%
# #Filter dates to consider only 2020 latest data 01-04- 2020 to 31-12 2020

# data_merged_sg=data_merged_sg[(data_merged_sg.created_date>'2020-01-01') & (data_merged_sg.created_date<'2021-01-01')]
# data_merged_sg.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %python
df_pd=df.toPandas()
df_pd.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[240]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>created_date</th>
#       <th>created_on</th>
#       <th>customer_id</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2020-10-23 17:46:57</td>
# ...

# %%
df_pd['lat']=df_pd['lat'].astype(float)
df_pd['lon']=df_pd['lon'].astype(float)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_pd=df_pd[df_pd.lat!=0]
df_pd.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[243]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>created_date</th>
#       <th>created_on</th>
#       <th>customer_id</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2020-10-23 17:46:57</td>
# ...

# %%
# %python
import time
import datetime, pytz

def time_to_utc(naive, timezone="Asia/Dubai"):
    local = pytz.timezone(timezone)
    local_dt = local.localize(naive, is_dst=None)
    utc_dt = local_dt.astimezone(pytz.utc)
    return utc_dt

def utc_to_time(naive, timezone="Asia/Dubai"):
    return naive.replace(tzinfo=pytz.utc).astimezone(pytz.timezone(timezone))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %python
# df_pd["year"]=df_pd["created_date"].apply(lambda x: str(x).split("-")[0])
# df_pd.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# df_pd=df_pd[(df_pd["year"].astype(int)<=2020)]
# df_pd=df_pd[(df_pd["year"].astype(int)<2022)]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# data_merged_sg_pd=data_merged_sg_pd[(data_merged_sg_pd["year"].astype(int)>=2019)]
# df_pd=df_pd[(df_pd["year"].astype(int)>2019)]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_pd['year'].max()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[247]: 2021</div>

# %%
df_pd['year'].min()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[248]: 2020</div>

# %%
df_pd.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[249]: created_date    datetime64[ns]
# created_on              object
# customer_id             object
# lat                    float64
# lon                    float64
# year                     int32
# dtype: object</div>

# %%
import pandas as pd
df_pd["created_date"]=pd.to_datetime(df_pd["created_date"])
df_pd.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[250]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>created_date</th>
#       <th>created_on</th>
#       <th>customer_id</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2020-10-23 17:46:57</td>
# ...

# %%
df_pd.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[251]: created_date    datetime64[ns]
# created_on              object
# customer_id             object
# lat                    float64
# lon                    float64
# year                     int32
# dtype: object</div>

# %%
# %python
df_pd["datetime_modifiedzone"]=df_pd["created_date"].apply(lambda x:utc_to_time(x))
df_pd.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[252]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>created_date</th>
#       <th>created_on</th>
#       <th>customer_id</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>year</th>
#       <th>datetime_modifiedzone</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
# ...

# %%
df_pd["datetime_modifiedzone"]=pd.to_datetime(df_pd["datetime_modifiedzone"])
df_pd["weekday"]=df_pd["datetime_modifiedzone"].apply(lambda x: x.isoweekday())
df_pd["hour"]=df_pd["datetime_modifiedzone"].apply(lambda x:x.hour)
df_pd.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[253]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>created_date</th>
#       <th>created_on</th>
#       <th>customer_id</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>year</th>
#       <th>datetime_modifiedzone</th>
#       <th>weekday</th>
#       <th>hour</th>
#     </tr>
# ...

# %%
# %python
df_pd=df_pd.drop(["year"],axis=1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Filter boundaries of GCC
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Boudning box gcc
df_pd=df_pd[(df_pd.lat>=16) & (df_pd.lat<33)]
df_pd=df_pd[(df_pd.lon>=34) & (df_pd.lon<60)]
df_pd.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[255]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>created_date</th>
#       <th>created_on</th>
#       <th>customer_id</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>datetime_modifiedzone</th>
#       <th>weekday</th>
#       <th>hour</th>
#     </tr>
#   </thead>
#   <tbody>
# ...

# %%
df_pd['customer_id'].nunique()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[257]: 16041</div>

# %%
# %python
# before 7 am in morning and after 8 pm in the evening = home location
df_home=df_pd[(df_pd["hour"]<7) | (df_pd["hour"]>20) ]
df_home.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[258]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>created_date</th>
#       <th>created_on</th>
#       <th>customer_id</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>datetime_modifiedzone</th>
#       <th>weekday</th>
#       <th>hour</th>
#     </tr>
#   </thead>
#   <tbody>
# ...

# %%
df_home['customer_id'].nunique()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[259]: 12439</div>

# %%
df_home.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[260]: created_date             160193
# created_on               160193
# customer_id              160193
# lat                      160193
# lon                      160193
# datetime_modifiedzone    160193
# weekday                  160193
# hour                     160193
# dtype: int64</div>

# %%
# %python
# for work location take weekdays only, Monday being 1st day of the week
df_work=df_pd[ (df_pd["weekday"]<5) | (df_pd["weekday"]>6)]

# before 8 pm and after 7 am = work location
df_work=df_work[((df_work["hour"]<=20) & (df_work["hour"]>=7)  ) ]

df_work.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[261]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>created_date</th>
#       <th>created_on</th>
#       <th>customer_id</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>datetime_modifiedzone</th>
#       <th>weekday</th>
#       <th>hour</th>
#     </tr>
#   </thead>
#   <tbody>
# ...

# %%
df_work['customer_id'].nunique()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[263]: 10950</div>

# %%
df_work.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[264]: created_date             123264
# created_on               123264
# customer_id              123264
# lat                      123264
# lon                      123264
# datetime_modifiedzone    123264
# weekday                  123264
# hour                     123264
# dtype: int64</div>

# %%
# %python
def get_centermost_point(cluster):
    
    converted_list_frommatrix=cluster.tolist()
    centroid = (MultiPoint(converted_list_frommatrix).centroid.x, MultiPoint(converted_list_frommatrix).centroid.y)
  
    return centroid
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %python
from sklearn.cluster import DBSCAN
from shapely.geometry import MultiPoint
kms_per_radian = 6371.0088 # WHAT IS THE PURPOSE OF THIS VALUE

def compute_cluster_per_user(list_of_points):
    
    number_points=len(list_of_points)
    coords=np.asmatrix(list_of_points)
  
    epsilon = 0.6/ kms_per_radian
    if(coords.shape[0]>=5): # WHY THIS CONDITION
        
        coordinates=np.radians(coords) # What if I don't convert it to radians ??
        db = DBSCAN(eps=epsilon, min_samples=4, algorithm='ball_tree', metric='haversine').fit(coordinates)
        
        cluster_labels = db.labels_
        
        unique_labels = set(cluster_labels)
        num_clusters = len(set(cluster_labels))
        
        clusters = pd.Series([coords[cluster_labels == n] for n in range(num_clusters)]) # Here we assigned the lables to the clusters 
        
        min_sample=4
        
        centermost_points = []
        for cluster in clusters.iteritems():
            if len(cluster[1]) >= min_sample:
                centermost_points.append((len(cluster[1]),get_centermost_point(cluster[1]))) # Apeending only the center point of each cluster ??
                 
        
        
        return centermost_points
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %python
import numpy as np
df_home_list=pd.DataFrame()
df_home_list=df_home[["customer_id","lat","lon"]].groupby("customer_id",as_index=False).aggregate(lambda x: list(x))
df_home_list.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[267]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customer_id</th>
#       <th>lat</th>
#       <th>lon</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10002762</td>
#       <td>[24.454267501831055, 24.45429039001465, 24.454...</td>
# ...

# %%
df_home_list["lat_long"]=list(zip(df_home_list["lat"],df_home_list["lon"]))
df_home_list.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[268]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customer_id</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>lat_long</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10002762</td>
#       <td>[24.454267501831055, 24.45429039001465, 24.454...</td>
# ...

# %%
# %python
df_home_list["lat_long_matrix"]=df_home_list["lat_long"].apply(lambda x:np.column_stack(x))
df_home_list.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[269]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customer_id</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>lat_long</th>
#       <th>lat_long_matrix</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10002762</td>
# ...

# %%
df_home_list["count_records"]=df_home_list["lat_long_matrix"].apply(lambda x:len(x))
df_home_list.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[270]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customer_id</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>lat_long</th>
#       <th>lat_long_matrix</th>
#       <th>count_records</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10002762</td>
# ...

# %%
df_home_list.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[271]: customer_id        12439
# lat                12439
# lon                12439
# lat_long           12439
# lat_long_matrix    12439
# count_records      12439
# dtype: int64</div>

# %%
df_home_list["clsuters_centroids"]=df_home_list["lat_long_matrix"].apply(lambda x:compute_cluster_per_user(x))
df_home_list.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[272]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customer_id</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>lat_long</th>
#       <th>lat_long_matrix</th>
#       <th>count_records</th>
#       <th>clsuters_centroids</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
# %python
# After sortin are we simply keeping first entry ?
def retreive_onlyhome_hotspot(list_of_centroids):
    if(list_of_centroids!=None):
        #print(len(list_of_centroids))
        if(len(list_of_centroids)>0):
            
            hotspot=sorted(list_of_centroids,key=lambda x: x[0], reverse=True)[0]
            
            home_lat=hotspot[1][0]
            home_lon=hotspot[1][1]
        #list_of_centroids
            return (home_lat,home_lon)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %python
df_home_list_remove_NULL_hotspots=df_home_list[df_home_list["clsuters_centroids"]!=None]

df_home_list_remove_NULL_hotspots["home"]=df_home_list_remove_NULL_hotspots["clsuters_centroids"].apply(retreive_onlyhome_hotspot)
df_home_list_remove_NULL_hotspots.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[275]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customer_id</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>lat_long</th>
#       <th>lat_long_matrix</th>
#       <th>count_records</th>
#       <th>clsuters_centroids</th>
#       <th>home</th>
#     </tr>
#   </thead>
#   <tbody>
# ...

# %%
df_home_list_remove_NULL_hotspots["home_lat"]=df_home_list_remove_NULL_hotspots["home"].apply(lambda x:  x[0] if (x!=None) else None)
df_home_list_remove_NULL_hotspots["home_lon"]=df_home_list_remove_NULL_hotspots["home"].apply(lambda x:  x[1] if (x!=None) else None)
df_home_list_remove_NULL_hotspots.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[276]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customer_id</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>lat_long</th>
#       <th>lat_long_matrix</th>
#       <th>count_records</th>
#       <th>clsuters_centroids</th>
#       <th>home</th>
#       <th>home_lat</th>
# ...

# %%
df_home_list_remove_NULL_hotspots[df_home_list_remove_NULL_hotspots.count_records<=4].count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[312]: customer_id           5116
# lat                   5116
# lon                   5116
# lat_long              5116
# lat_long_matrix       5116
# count_records         5116
# clsuters_centroids       0
# home                     0
# home_lat                 0
# home_lon                 0
# dtype: int64</div>

# %%
df_home_list_remove_NULL_hotspots.home.isna().sum()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[313]: 5503</div>

# %%
# df_home_list_remove_NULL_hotspots[df_home_list_remove_NULL_hotspots.home_lat==0]
# df_home_list_remove_NULL_hotspots[df_home_list_remove_NULL_hotspots.columns[df_home_list_remove_NULL_hotspots.isna().any()]]
df_home_list_remove_NULL_hotspots.home_lat.isna().sum()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[314]: 5503</div>

# %%
df_home_list_remove_NULL_hotspots_homeloc=df_home_list_remove_NULL_hotspots[['customer_id','home_lat',"home_lon"]]
df_home_list_remove_NULL_hotspots_homeloc.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[315]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customer_id</th>
#       <th>home_lat</th>
#       <th>home_lon</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10002762</td>
#       <td>24.454352</td>
#       <td>54.673175</td>
#     </tr>
#     <tr>
# ...

# %%
df_home_list_remove_NULL_hotspots_homeloc['customer_id'].nunique()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[316]: 12439</div>

# %%
# %python
df_home_list_remove_NULL_hotspots_homeloc=df_home_list_remove_NULL_hotspots_homeloc.fillna(0)
df_home_list_remove_NULL_hotspots_homeloc=df_home_list_remove_NULL_hotspots_homeloc[df_home_list_remove_NULL_hotspots_homeloc.home_lat!=0]
df_home_list_remove_NULL_hotspots_homeloc.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[317]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customer_id</th>
#       <th>home_lat</th>
#       <th>home_lon</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10002762</td>
#       <td>24.454352</td>
#       <td>54.673175</td>
#     </tr>
#     <tr>
# ...

# %%
df_home_list_remove_NULL_hotspots_homeloc['customer_id'].nunique()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[318]: 6936</div>

# %%
df_home_list_remove_NULL_hotspots_homeloc.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[319]: customer_id    6936
# home_lat       6936
# home_lon       6936
# dtype: int64</div>

# %%
# %python

df_work_list=pd.DataFrame()
df_work_list=df_work[["customer_id","lat","lon"]].groupby("customer_id",as_index=False).aggregate(lambda x: list(x))
df_work_list["lat_long"]=list(zip(df_work_list["lat"],df_work_list["lon"]))
df_work_list["lat_long_matrix"]=df_work_list["lat_long"].apply(lambda x:np.column_stack(x))
df_work_list["count_records"]=df_work_list["lat_long_matrix"].apply(lambda x:len(x))
df_work_list.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[320]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customer_id</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>lat_long</th>
#       <th>lat_long_matrix</th>
#       <th>count_records</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10000969</td>
# ...

# %%
# %python
df_work_list["clsuters_centroids"]=df_work_list["lat_long_matrix"].apply(compute_cluster_per_user)
df_work_list.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[321]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customer_id</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>lat_long</th>
#       <th>lat_long_matrix</th>
#       <th>count_records</th>
#       <th>clsuters_centroids</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
# %python
df_work_list_remove_NULL_hotspots=df_work_list[df_work_list["clsuters_centroids"]!=None]

df_work_list_remove_NULL_hotspots["work"]=df_work_list_remove_NULL_hotspots["clsuters_centroids"].apply(retreive_onlyhome_hotspot)
df_work_list_remove_NULL_hotspots["work_lat"]=df_work_list_remove_NULL_hotspots["work"].apply(lambda x:  x[0] if (x!=None) else None)

df_work_list_remove_NULL_hotspots["work_lon"]=df_work_list_remove_NULL_hotspots["work"].apply(lambda x:  x[1] if (x!=None) else None)

df_work_list_remove_NULL_hotspots_workloc=df_work_list_remove_NULL_hotspots[['customer_id','work_lat',"work_lon"]]

df_work_list_remove_NULL_hotspots_workloc.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[322]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customer_id</th>
#       <th>work_lat</th>
#       <th>work_lon</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10000969</td>
#       <td>NaN</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
# ...

# %%
df_work_list_remove_NULL_hotspots_workloc=df_work_list_remove_NULL_hotspots_workloc.fillna(0)
df_work_list_remove_NULL_hotspots_workloc=df_work_list_remove_NULL_hotspots_workloc[df_work_list_remove_NULL_hotspots_workloc.work_lat!=0]
df_work_list_remove_NULL_hotspots_workloc.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[323]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customer_id</th>
#       <th>work_lat</th>
#       <th>work_lon</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>10001001</td>
#       <td>24.248751</td>
#       <td>55.732639</td>
#     </tr>
#     <tr>
# ...

# %%
df_work_list_remove_NULL_hotspots_workloc['customer_id'].nunique()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[324]: 5607</div>

# %%
# -- Check if home and work loc are same ..in that case we take other one..
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
##Check for home-work similar or not and remove accordingly
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %python

df_home_info=df_home_list_remove_NULL_hotspots[['customer_id','clsuters_centroids','home_lat','home_lon']]
df_work_info=df_work_list_remove_NULL_hotspots[['customer_id','clsuters_centroids','work_lat','work_lon']]
df_home_info.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[326]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customer_id</th>
#       <th>clsuters_centroids</th>
#       <th>home_lat</th>
#       <th>home_lon</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10002762</td>
# ...

# %%
# %python
df_home_work_correction=pd.merge(df_home_info,df_work_info,on="customer_id",how="left")
df_home_work_correction.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[327]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customer_id</th>
#       <th>clsuters_centroids_x</th>
#       <th>home_lat</th>
#       <th>home_lon</th>
#       <th>clsuters_centroids_y</th>
#       <th>work_lat</th>
#       <th>work_lon</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
# %python
df_home_work_correction=df_home_work_correction.fillna(0)
df_home_work_correction.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[328]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customer_id</th>
#       <th>clsuters_centroids_x</th>
#       <th>home_lat</th>
#       <th>home_lon</th>
#       <th>clsuters_centroids_y</th>
#       <th>work_lat</th>
#       <th>work_lon</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %%
df_home_work_correction=df_home_work_correction[df_home_work_correction.home_lat!=0]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %python
from geopy.distance import great_circle
def compute_closeness_home_work(home_lat,home_lon,work_lat,work_lon):
    home=(home_lat,home_lon)
    work=(work_lat,work_lon)
    dist=great_circle(home, work).km
    return dist
    
df_home_work_correction["dist"]=df_home_work_correction.apply(lambda x:compute_closeness_home_work(x["home_lat"],x["home_lon"],x["work_lat"],x["work_lon"]),axis=1 )
df_home_work_correction.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[330]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customer_id</th>
#       <th>clsuters_centroids_x</th>
#       <th>home_lat</th>
#       <th>home_lon</th>
#       <th>clsuters_centroids_y</th>
#       <th>work_lat</th>
#       <th>work_lon</th>
#       <th>dist</th>
#     </tr>
#   </thead>
# ...

# %%
# %python
df_home_work_correction_actual=df_home_work_correction[df_home_work_correction.dist>1]

df_home_work_correction_actual=df_home_work_correction_actual[["customer_id","home_lat","home_lon"]]
df_home_work_correction_actual.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[331]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customer_id</th>
#       <th>home_lat</th>
#       <th>home_lon</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>10002762</td>
#       <td>24.454352</td>
#       <td>54.673175</td>
#     </tr>
#     <tr>
# ...

# %%
df_home_work_correction_needscorr=df_home_work_correction[df_home_work_correction.dist<=1]
df_home_work_correction_needscorr.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[332]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customer_id</th>
#       <th>clsuters_centroids_x</th>
#       <th>home_lat</th>
#       <th>home_lon</th>
#       <th>clsuters_centroids_y</th>
#       <th>work_lat</th>
#       <th>work_lon</th>
#       <th>dist</th>
#     </tr>
#   </thead>
# ...

# %%
# %python

from ast import literal_eval
from operator import itemgetter, attrgetter 

# what exactly is this function doing here ??
def compute_appropriate_home_lat(x):
    #print(x)
    if((x!=0) or (x!='')):
      
      centroid_list=list(x)
    
      centroid_list=sorted(centroid_list, key=itemgetter(0))
    
      if(len(centroid_list)>1):
        
        approprite_home=centroid_list[-2]
        return approprite_home[1][0]
        
      if(len(centroid_list)==1):
      
          approprite_home=centroid_list[0]
        
          return approprite_home[1][0]
    
def compute_appropriate_home_lon(x):
  
  if((x!=0) or (x!='')):
    
      centroid_list=list(x)
      centroid_list=sorted(centroid_list, key=itemgetter(0))
      if(len(centroid_list)>1):
        
        
        
    
        approprite_home=centroid_list[-2]
        return approprite_home[1][1]
        
      if(len(centroid_list)==1):
      
          approprite_home=centroid_list[0]
          return approprite_home[1][1]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %python
df_home_work_correction_needscorr["clsuters_centroids_x"]=df_home_work_correction_needscorr["clsuters_centroids_x"].fillna(0)
df_home_work_correction_needscorr.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/local_disk0/tmp/1613935706180-0/PythonShell.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# Out[334]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# ...

# %%
# %python
df_home_work_correction_needscorr=df_home_work_correction_needscorr[(df_home_work_correction_needscorr.clsuters_centroids_x!=0) & (df_home_work_correction_needscorr.clsuters_centroids_y!=0)]
df_home_work_correction_needscorr.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[335]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customer_id</th>
#       <th>clsuters_centroids_x</th>
#       <th>home_lat</th>
#       <th>home_lon</th>
#       <th>clsuters_centroids_y</th>
#       <th>work_lat</th>
#       <th>work_lon</th>
#       <th>dist</th>
#     </tr>
#   </thead>
# ...

# %%
# %python
df_home_work_correction_needscorr["new_home_lat"]=df_home_work_correction_needscorr["clsuters_centroids_x"].apply(lambda x:compute_appropriate_home_lat(x))
df_home_work_correction_needscorr["new_home_lon"]=df_home_work_correction_needscorr["clsuters_centroids_x"].apply(lambda x:compute_appropriate_home_lon(x))

df_home_work_correction_needscorr.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[336]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customer_id</th>
#       <th>clsuters_centroids_x</th>
#       <th>home_lat</th>
#       <th>home_lon</th>
#       <th>clsuters_centroids_y</th>
#       <th>work_lat</th>
#       <th>work_lon</th>
#       <th>dist</th>
# ...

# %%
# %python

df_home_work_corrected=df_home_work_correction_needscorr[['customer_id','new_home_lat','new_home_lon']]
df_home_work_corrected.columns=['customer_id','home_lat','home_lon']
df_home_work_corrected.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[337]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customer_id</th>
#       <th>home_lat</th>
#       <th>home_lon</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>6</th>
#       <td>10006451</td>
#       <td>24.489524</td>
#       <td>54.609480</td>
#     </tr>
#     <tr>
# ...

# %%
# %python
df_home_after_corrections=pd.concat([df_home_work_corrected,df_home_work_correction_actual],axis=0)
df_home_after_corrections.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[338]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customer_id</th>
#       <th>home_lat</th>
#       <th>home_lon</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>6</th>
#       <td>10006451</td>
#       <td>24.489524</td>
#       <td>54.609480</td>
#     </tr>
#     <tr>
# ...

# %%
df_work_info_after=df_work_info[['customer_id','work_lat','work_lon']]
df_work_info_after=df_work_info_after.fillna(0)
df_work_info_after=df_work_info_after[df_work_info_after.work_lat!=0]
df_work_info_after.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[339]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customer_id</th>
#       <th>work_lat</th>
#       <th>work_lon</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>10001001</td>
#       <td>24.248751</td>
#       <td>55.732639</td>
#     </tr>
#     <tr>
# ...

# %%
df_home_after_corrections['tag']='Home'
df_work_info_after['tag']='Work'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_home_after_corrections.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[342]: customer_id    6936
# home_lat       6936
# home_lon       6936
# tag            6936
# dtype: int64</div>

# %%
df_work_info_after.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[343]: customer_id    5607
# work_lat       5607
# work_lon       5607
# tag            5607
# dtype: int64</div>

# %%
df_work_info_after.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[344]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customer_id</th>
#       <th>work_lat</th>
#       <th>work_lon</th>
#       <th>tag</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>10001001</td>
#       <td>24.248751</td>
#       <td>55.732639</td>
# ...

# %%
df_work_info_after.columns=['customer_id','lat','lon','tag']
df_home_after_corrections.columns=['customer_id','lat','lon','tag']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df_work_info_after=df_work_info_after.drop_duplicates('customer_id')
df_home_after_corrections=df_home_after_corrections.drop_duplicates('customer_id')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
final_home_work=pd.concat([df_home_after_corrections,df_work_info_after],axis=0)
final_home_work.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[347]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customer_id</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>tag</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>6</th>
#       <td>10006451</td>
#       <td>24.489524</td>
#       <td>54.609480</td>
# ...

# %%
from shapely.geometry import Point, shape
import fiona
point = Point(55.205124,25.16231)

#input_path="abfss://source@entadlsv2.dfs.core.windows.net/DataSources/libraries/UAE_Corrected_Communities.shp"

# How did we generated this file?
fc = fiona.open("/dbfs/mnt/DataSources/libraries/UAE_Corrected_Communities.shp")
print(point)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">POINT (55.205124 25.16231)
# </div>

# %%
# for feature in fc:
#   print(feature['geometry']['coordinates'])
#   if shape(feature['geometry']).contains(point):
#     print("entered here")
#     print('props',feature['properties'])
#     print(feature['properties']['zone_name_'], feature['properties']['city_id'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
def compute_neighborhood(geom):
    lon=geom["lon"]
    lat=geom["lat"]
    point=Point(lon,lat)
    for feature in fc:
        if shape(feature['geometry']).contains(point):
                #print("entered here")
                #print(feature['properties']['zone_name_'], feature['properties']['city_id'])
                #neighborhood=feature['properties']['zone_name_']
                emirate=feature['properties']['city_id']
                return (emirate)

def compute_zone_name(geom):
    lon=geom["lon"]
    lat=geom["lat"]
    point=Point(lon,lat)
    for feature in fc:
        if shape(feature['geometry']).contains(point):
                z_name=feature['properties']['zone_name_']
                return (z_name)

def compute_zone_geo(geom):
    lon=geom["lon"]
    lat=geom["lat"]
    point=Point(lon,lat) 
    for feature in fc:
        if shape(feature['geometry']).contains(point):
                z_geo=feature['geometry']
                return (z_geo)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
final_home_work["Emirate"]=final_home_work[["lat","lon"]].apply(compute_neighborhood,axis=1)
final_home_work["zone_name"]=final_home_work[["lat","lon"]].apply(compute_zone_name,axis=1)
#final_home_work["zone_geometry"]=final_home_work[["lat","lon"]].apply(compute_zone_geo,axis=1)
final_home_work.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[350]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customer_id</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>tag</th>
#       <th>Emirate</th>
#       <th>zone_name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>6</th>
#       <td>10006451</td>
# ...

# %%
# Tag Null to out of UAE area
final_home_work.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[352]: customer_id    12543
# lat            12543
# lon            12543
# tag            12543
# Emirate        12529
# zone_name      12529
# dtype: int64</div>

# %%
final_home_work['Emirate']=final_home_work['Emirate'].fillna('unknown')
final_home_work.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[353]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customer_id</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>tag</th>
#       <th>Emirate</th>
#       <th>zone_name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>6</th>
#       <td>10006451</td>
# ...

# %%
final_home_work['tag_location']=final_home_work["Emirate"].apply(lambda x: 'RestofGCC' if x=='unknown' else 'UAE')
final_home_work.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[354]: </div>
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>customer_id</th>
#       <th>lat</th>
#       <th>lon</th>
#       <th>tag</th>
#       <th>Emirate</th>
#       <th>zone_name</th>
#       <th>tag_location</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>6</th>
# ...

# %%
# final_home_work_sp=spark.createDataFrame(final_home_work[['customer_id','lat','lon','tag_location','tag']])
final_home_work_sp=spark.createDataFrame(final_home_work)
final_home_work_sp.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+------------------+------------------+----+-------+--------------------+------------+
# customer_id|               lat|               lon| tag|Emirate|           zone_name|tag_location|
# +-----------+------------------+------------------+----+-------+--------------------+------------+
#    10006451| 24.48952433268229| 54.60948028564453|Home|    AUH|          YAS ISLAND|         UAE|
#    10017925| 24.48853639455942|54.359312497652496|Home|    AUH|       Al Markaziyah|         UAE|
#    10025961| 25.12323760986328| 55.22198486328125|Home|    DXB|AL QOUZE IND.THIR...|         UAE|
# ...

# %%
final_home_work_sp.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[356]: 12543</div>

# %%
final_home_work_sp.select('customer_id').distinct().count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[357]: 8928</div>

# %%
# %sql
# drop table if exists irumdb.aldar_homework_2020
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# final_home_work_sp.write.format('delta').mode('overwrite').saveAsTable("irumdb.aldar_homework_2020")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %python
df_user = spark.read.format("org.apache.spark.sql.jdbc").option("url", "jdbc:sqlserver://entdwh.database.windows.net:1433;database=ENTDWH;user=iramz_dwh;password=Ir@m0702Z@rA").option("tempDir", "abfss://source@entadlsv2.dfs.core.windows.net/DataSources/temp_dir") \
  .option("forwardSparkAzureStorageCredentials", "true") \
  .option("query", "select k.user_id, k.company_tier_name from dbo.user_wl_keys k left join dbo.user_dim u on k.user_id = u.user_id where k.company_code = 'adr' and k.activation_key not like 'tst%' and k.activation_key not like 'test%' and u.email not like 'testqa%' and u.email not like 'qatest%' and u.active_flag = 1").load()
df_user.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %python
final_home_work_sp_sg=final_home_work_sp.join(df_user, final_home_work_sp.customer_id ==df_user.user_id).drop(df_user.user_id)
final_home_work_sp_sg.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">NameError</span>                                 Traceback (most recent call last)
# ...

# %%
final_home_work_sp_sg.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
final_home_work_sp_sg.select('customer_id').distinct().count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[129]: 8577</div>

# %%
# %sql
# drop table if exists aldar_user_locations.aldar_users_home_work_locations
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
# final_home_work_sp_sg.write.format('delta').mode('overwrite').saveAsTable('aldar_user_locations.aldar_users_home_work_locations')
final_home_work_sp.write.format('delta').mode('overwrite').saveAsTable('aldar_user_locations.aldar_users_home_work_locations')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# final_home_work_sp_sg.coalesce(1).write.format("com.databricks.spark.csv").option("header", "true").save("dbfs:/FileStore/df/irum/2_alfuttaim_homework_2020.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#final_home_work_sp_sg.to_csv("/dbfs/FileStore/df/irum/alfuttaim_homework_2020.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# https://westeurope.azuredatabricks.net/files/df/irum/alfuttaim_homework_2020.csv?o=8767374559588946
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# import pandas as pd
# pd.Timestamp.min
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[1]: Timestamp(&#39;1677-09-21 00:12:43.145225&#39;)</div>

# %%
# pd.Timestamp.max
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: Timestamp(&#39;2262-04-11 23:47:16.854775807&#39;)</div>

# %%
from datetime import datetime,timedelta,date
today = date.today()
daybeforeyesterday = today - timedelta(days = 1)
daybeforeyesterday
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: datetime.date(2021, 2, 28)</div>
